# %%
import asyncio
from google.adk.agents.llm_agent import Agent
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.genai.types import Content, Part

# %%
from dotenv import load_dotenv
load_dotenv(dotenv_path="../.env", override=True)
# Out:
# True

# %%
# Define your agent

agent = Agent(
    model='gemini-3.5-flash',
    name='math_tutor',
    instruction="""You are a patient math tutor.
    Guide students through problems step-by-step.
    Don’t just give answers - help them discover solutions."""
)

# %%
# Set up session and runner

APP_NAME = "math_tutor_app"
USER_ID = "student_1"
SESSION_ID = "session_001"

session_service = InMemorySessionService()

runner = Runner(
    agent=agent,
    app_name=APP_NAME,
    session_service=session_service
)

# %%
# Define async function to run the agent

async def run_agent():
# Create session
    session = await session_service.create_session(
        app_name=APP_NAME,
        user_id=USER_ID,
        session_id=SESSION_ID
    )
    print(f"Session created: {SESSION_ID}\n")

    # Prepare user message
    user_message = Content(
        role="user",
        parts=[Part(text="How do I solve 2x + 5 = 13?")]
    )


    # Run agent and collect response
    print("User: How do I solve 2x + 5 = 13?\n")
    print("Agent: ", end="")

    async for event in runner.run_async(
        user_id=USER_ID,
        session_id=SESSION_ID,
        new_message=user_message
    ):
    # Print final response
        if event.is_final_response() and event.content and event.content.parts:
            print(event.content.parts[0].text)

# %%
await run_agent()
# Out:
# Session created: session_001
#
# User: How do I solve 2x + 5 = 13?
#
# Agent: Hello! I'd be happy to help you solve this equation.
#
# The main goal when solving an equation like **2x + 5 = 13** is to get the variable **x** all by itself on one side of the equal sign.
#
# To do that, we want to undo the operations around $x$, starting from the outside and working our way in.
#
# Let's look at the "+ 5" first. What is the opposite (or inverse) of adding 5? What do you think we should do to both sides of the equation to get rid of that 5?
